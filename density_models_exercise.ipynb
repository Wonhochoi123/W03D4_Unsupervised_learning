# %%
# import matplotlib
import matplotlib.pyplot as plt

# set figure size
plt.rcParams["figure.figsize"] = (12,8)

#import numpy
import numpy as np

# from sklearn import make_blobs
from sklearn.datasets import make_blobs

# import DBSCAN
from sklearn.cluster import DBSCAN

# %% [markdown]
# ## Task: Generate clusters with make_blobs function
#
# * use this settings:
#     * n_samples=150,
#     * n_features=2,
#     * centers=3,
#     * cluster_std=0.6,
#     * random_state=0

# %%
# import libraries
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np

# generate clusters 
X, y = make_blobs(n_samples=150,
                  n_features=2,
                  centers=3,
                  cluster_std=0.6,
                  random_state=0)

# %% [markdown]
# * plot data points

# %%
# set figure size
plt.rcParams["figure.figsize"] = (12,8)

# plot clusters
plt.scatter(X[:,0],
            X[:,1],
            c='black',
            marker='o')
plt.grid()
plt.show()

# %% [markdown]
# * define function plot_clusters

# %%
def plot_clusters(X,y_res, plt_cluster_centers = False):
    X_centroids = []
    Y_centroids = []

    for cluster in set(y_res):
        x = X[y_res == cluster,0]
        y = X[y_res == cluster,1]
        X_centroids.append(np.mean(x))
        Y_centroids.append(np.mean(y))

        plt.scatter(x,
                    y,
                    s=50,
                    marker='o',
                    label=f'cluster {cluster}')

    if plt_cluster_centers:
        plt.scatter(X_centroids,
                    Y_centroids,
                    marker='*',
                    c='red',
                    s=250,
                    label='centroids')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## Objective:
# Try to find optimal settings of `eps` and `min_samples` params of DBSCAN. You can iterate over multiple parameters combinations and plot the clustering results.

# %% [markdown]
# * define params space

# %%
L_eps=[i/10 for i in range(4,10)]
L_eps
# Out:
# [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]

# %%
L_sam=[i for i in range(2,6)]
L_sam
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# * combinations (hint: use 'product' function from 'itertools')

# %%
from itertools import product 
for k in  list(product(L_eps, L_sam)):
    db = DBSCAN(eps=k[0],
            min_samples=k[1],
            metric='euclidean')
    # fit and predicr
    y_db = db.fit_predict(X)
    # Plot DBSCAN clusters
    plot_clusters(X,y_db)
    print(k)
# Out:
# (0.4, 2)
# (0.4, 3)
# (0.4, 4)
# (0.4, 5)
# (0.5, 2)
# (0.5, 3)
# (0.5, 4)
# (0.5, 5)
# (0.6, 2)
# (0.6, 3)
# (0.6, 4)
# (0.6, 5)
# (0.7, 2)
# (0.7, 3)
# (0.7, 4)
# (0.7, 5)
# (0.8, 2)
# (0.8, 3)
# (0.8, 4)
# (0.8, 5)
# (0.9, 2)
# (0.9, 3)
# (0.9, 4)
# (0.9, 5)

# %%
# import DBSCAN
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=0.6,
            min_samples=4,
            metric='euclidean')
# fit and predicr
y_db = db.fit_predict(X)
# Plot DBSCAN clusters
plot_clusters(X,y_db)
